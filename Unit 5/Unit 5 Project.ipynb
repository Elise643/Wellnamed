# %% [markdown]
# <a href="https://colab.research.google.com/github/Elise643/Wellnamed/blob/main/Unit%205/Unit%205%20Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Unit 5 Project
# I found a dataset about names and gender, so I wanted to see if there was any correlation between where a name is in the alphabet and the gender of the person it's most commonly assigned to. This dataset included many uncommon names which only a single or just a few people had, so those have been omitted.

# %%
# !pip install ucimlrepo
# !pip install preliz
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 519.1/519.1 kB 3.8 MB/s eta 0:00:00
# ...

# %%
from ucimlrepo import fetch_ucirepo

gender_by_name = fetch_ucirepo(id=591)
data = gender_by_name.data.features

data=data.sort_values(by="Name")
data
# Out:
#            Name Gender  Count   Probability
# 114150        A      M      2  5.473480e-09
# 112246        A      F      2  5.473480e-09
# 115618    A'Aff      F      1  2.736740e-09
# 133954   A'Aron      M      1  2.736740e-09
# 115619   A'Dele      F      1  2.736740e-09
# ...         ...    ...    ...           ...
# 110558   Zyvion      M      5  1.368370e-08
# 90632     Zyvon      M      7  1.915720e-08
# 94120   Zyyanna      F      6  1.642040e-08
# 96225     Zyyon      M      6  1.642040e-08
# 87147     Zzyzx      M     10  2.736740e-08
#
# [147269 rows x 4 columns]

# %%
# !pip install preliz

# %%
import arviz as az
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import pymc as pm
import preliz as pz
import seaborn as sns
from sklearn import tree

# %%
female=data[data['Gender']=='F']
male = data[data['Gender']=='M']

# %%
print("The female list is of length "+str(len(female))+" and the male list is of length "+str(len(male))+" which means the female list is "+str(len(female)-len(male))+" rows longer than the male")

sf=female[female['Count']>=5]
sm=male[male['Count']>=5]
# Out:
# The female list is of length 89749 and the male list is of length 57520 which means the female list is 32229 rows longer than the male

# %%
sf=sf.sort_values(by='Count')
sf = sf.reset_index(drop=True)
sf[sf['Count']==5][0:100]
#plt.scatter(sm.index,sm['Count'])
# Out:
#            Name Gender  Count   Probability
# 0        Danuel      F      5  1.368370e-08
# 1        Tamhra      F      5  1.368370e-08
# 2       Tamiaya      F      5  1.368370e-08
# 3       Tamicko      F      5  1.368370e-08
# 4       Tameera      F      5  1.368370e-08
# ..          ...    ...    ...           ...
# 95      Tamyria      F      5  1.368370e-08
# 96       Armaya      F      5  1.368370e-08
# 97  Ngozichukwu      F      5  1.368370e-08
# 98      Tammyra      F      5  1.368370e-08
# 99       Nevach      F      5  1.368370e-08
#
# [100 rows x 4 columns]
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['Count']
#                 .value_counts()
# ...

# %% [markdown]
# Hm. Even omitting the least common names we still have some such as Zzyzx, Aaronjacob, Trevorjames (no, this isn't data error, these people just have two first names stuck together), and countless others (well, 5464 for the males where only 5 people have them and 8869 for the females). Plenty of tragedeigh style names as well.
